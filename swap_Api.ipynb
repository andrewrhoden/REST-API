# %% [markdown]
# we have an endpoint with 82 people records
# we have 10 per page
# we have 9 total pages
#
# base url: https://swapi.dev/api/people/?page='

# %% [markdown]
# We need to get all of the pages into one Python List.
#
# Psuedo-Code
#
# I want to make a for loop that loops through every page -I need to increase the page number of the URL by 1 every time I move through the loop -pagenum + 1 -pagenum + i
# Concept: I need to extract the data I am looking for into a data structure (list) -need to create a list
#
# Make a get request -I need to save the response to the request in a variable
#
# Need to turn our response into a data type we can use later .loads() .json()
#
# .append the converted response into the list

# %%
import requests
import json
from pprint import pp
import math

# %% [markdown]
# test one page first before we loop through the whole pages

# %%
first_page_url='https://swapi.dev/api/people/?page=1'
response=requests.get(first_page_url)
fetchdata=response.json() 
pp(fetchdata)
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#               'height': '172',
#               'mass': '77',
#               'hair_color': 'blond',
#               'skin_color': 'fair',
#               'eye_color': 'blue',
#               'birth_year': '19BBY',
#               'gender': 'male',
#               'homeworld': 'https://swapi.dev/api/planets/1/',
#               'films': ['https://swapi.dev/api/films/1/',
#                         'https://swapi.dev/api/films/2/',
#                         'https://swapi.dev/api/films/3/',
#                         'https://swapi.dev/api/films/6/'],
#               'species': [],
#               'vehicles': ['https://swapi.dev/api/vehicles/14/',
#                            'https://swapi.dev/api/vehicles/30/'],
#               'starships': ['https://swapi.dev/api/starships/12/',
#                             'https://swapi.dev/api/starships/22/'],
# ...

# %%
baseurl='https://swapi.dev/api/people/?page='
total_pages=9

data=[]
for i in range(1,total_pages+1): #loop through the len of pages
    response=requests.get(baseurl + str(i)) #this will get every page from the loop. page 1,1,3,etc
    new_response=response.json()
    data.append(new_response) #add data to a list 
pp(data) #format the data in a more readable format using pretty print module
# Out:
# [{'count': 82,
#   'next': 'https://swapi.dev/api/people/?page=2',
#   'previous': None,
#   'results': [{'name': 'Luke Skywalker',
#                'height': '172',
#                'mass': '77',
#                'hair_color': 'blond',
#                'skin_color': 'fair',
#                'eye_color': 'blue',
#                'birth_year': '19BBY',
#                'gender': 'male',
#                'homeworld': 'https://swapi.dev/api/planets/1/',
#                'films': ['https://swapi.dev/api/films/1/',
#                          'https://swapi.dev/api/films/2/',
#                          'https://swapi.dev/api/films/3/',
#                          'https://swapi.dev/api/films/6/'],
#                'species': [],
#                'vehicles': ['https://swapi.dev/api/vehicles/14/',
#                             'https://swapi.dev/api/vehicles/30/'],
#                'starships': ['https://swapi.dev/api/starships/12/',
# ...

# %% [markdown]
# We now have everything in one list!
#
# But there are keys that we do not need for the questions that are being asked.
#
# Let's get the values of the results keys in one list.
#
# We need to loop through the list. Then you call the key for that list index, in this case it is the 'result' key We want to store it in a seperate list so all of have left to work with is our character data.

# %%
#Checking to see how to get the information that we want.
print(data[0]['results'])

cleaned_data= []

# test using nested for loop method.
for list_page in data:
    #print(list_page)
    #print(data[i])
    pass
    for values in list_page['results']:
        #print(values)
        pass

#print(cleaned_data)

# finally use this shorter for loop that works to get the information
for num in range(0, 9):
    results= data[num]['results']
    cleaned_data.extend(results)

pp(cleaned_data)
# Out:
# [{'name': 'Luke Skywalker', 'height': '172', 'mass': '77', 'hair_color': 'blond', 'skin_color': 'fair', 'eye_color': 'blue', 'birth_year': '19BBY', 'gender': 'male', 'homeworld': 'https://swapi.dev/api/planets/1/', 'films': ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/3/', 'https://swapi.dev/api/films/6/'], 'species': [], 'vehicles': ['https://swapi.dev/api/vehicles/14/', 'https://swapi.dev/api/vehicles/30/'], 'starships': ['https://swapi.dev/api/starships/12/', 'https://swapi.dev/api/starships/22/'], 'created': '2014-12-09T13:50:51.644000Z', 'edited': '2014-12-20T21:17:56.891000Z', 'url': 'https://swapi.dev/api/people/1/'}, {'name': 'C-3PO', 'height': '167', 'mass': '75', 'hair_color': 'n/a', 'skin_color': 'gold', 'eye_color': 'yellow', 'birth_year': '112BBY', 'gender': 'n/a', 'homeworld': 'https://swapi.dev/api/planets/1/', 'films': ['https://swapi.dev/api/films/1/', 'https://swapi.dev/api/films/2/', 'https://swapi.dev/api/films/
# ...

# %% [markdown]
# 1. Create a function that returns a list of all the names.
# 2. Create a function that counts the total number of males and females. Return both numbers
# 3. Create a function that returns a list of all the charachters that appear in more than x number of films. Where 'x' is the number of films you are checking for and is passed into the function.
# 4. Create function that returns a tuple of the min, max, and avg height for all charachters
# 5. Create a function that accepts two arguements: eye color and hair color. Return a dictionary with the min, max, and avg height based on the parameters.
# Challenge 1: get all of the response data into a list using a while loop instead of a for loop
# challenge 2: For problem number 4,convert the centimeters to feet
# Challenge: Create a function that that returns a list of all the names that start with a certain letter.

# %% [markdown]
# 1. Create a function that returns a list of all the names.

# %%
def list_of_names():
    name_list=[]
    for i in range (len(cleaned_data)):
        name_list.append(cleaned_data[i]['name']) 
    return name_list
list_of_names()
# Out:
# ['Luke Skywalker',
#  'C-3PO',
#  'R2-D2',
#  'Darth Vader',
#  'Leia Organa',
#  'Owen Lars',
#  'Beru Whitesun lars',
#  'R5-D4',
#  'Biggs Darklighter',
#  'Obi-Wan Kenobi',
#  'Anakin Skywalker',
#  'Wilhuff Tarkin',
#  'Chewbacca',
#  'Han Solo',
#  'Greedo',
#  'Jabba Desilijic Tiure',
#  'Wedge Antilles',
#  'Jek Tono Porkins',
#  'Yoda',
#  'Palpatine',
#  'Boba Fett',
#  'IG-88',
#  'Bossk',
#  'Lando Calrissian',
#  'Lobot',
#  'Ackbar',
#  'Mon Mothma',
#  'Arvel Crynyd',
#  'Wicket Systri Warrick',
#  'Nien Nunb',
#  'Qui-Gon Jinn',
#  'Nute Gunray',
#  'Finis Valorum',
#  'Padmé Amidala',
#  'Jar Jar Binks',
#  'Roos Tarpals',
#  'Rugor Nass',
#  'Ric Olié',
#  'Watto',
#  'Sebulba',
#  'Quarsh Panaka',
#  'Shmi Skywalker',
#  'Darth Maul',
#  'Bib Fortuna',
#  'Ayla Secura',
#  'Ratts Tyerel',
#  'Dud Bolt',
#  'Gasgano',
#  'Ben Quadinaros',
#  'Mace Windu',
#  'Ki-Adi-Mundi',
#  'Kit Fisto',
#  'Eeth Koth',
#  'Adi Gallia',
#  'Saesee Tiin',
#  'Yarael Poof',
# ...

# %% [markdown]
# Create a function that counts the total number of males and females. Return both numbers

# %%
def count_sex():
    male_counter=0
    female_counter=0
    for person in range(len(cleaned_data)):
        if cleaned_data[person]['gender']=='male':
            male_counter+=1
        elif cleaned_data[person]['gender']=='female':
            female_counter+=1
    print(f"The total female count is: {female_counter}. \n The total Male count is: {male_counter} ")
count_sex()
# Out:
# The total female count is: 17.
#  The total Male count is: 60

# %% [markdown]
#  Create a function that returns a list of all the characters that appear in more than x number of films. Where 'x' is the number of films you are checking for and is passed into the function.

# %%
def count_characters(x):

    all_characters=[]
    for name in cleaned_data:
       if len(name['films']) >=x:
        all_characters.append( name['name'])
    return all_characters
count_characters(5)
# Out:
# ['C-3PO', 'R2-D2', 'Obi-Wan Kenobi', 'Yoda', 'Palpatine']

# %% [markdown]
# Create function that returns a tuple of the min, max, and avg height for all characters

# %%
def character_heights():
    
    for l in range(len(cleaned_data)):
       for m in 

character_heights()

# %% [markdown]
# Create a function that accepts two arguements: eye color and hair color. Return a dictionary with the min, max, and avg height based on the parameters.

# %%
def eye_color(eye_colr,hair_colr):
    lst_height=[]
    results=[]
    for i in cleaned_data:
        if i['eye_color'] == eye_colr and i['hair_color'] == hair_colr: #and i['heights'].isnumeric():
            #if i['height'].isnumeric():
                lst_height.append(i['height'])
                for value in lst_height:
                    if value.isnumeric():
                        results.append(int(value))


                
    minimum_height= min(results)
    maximum_height=max(results)
    avg_height=round(sum(results)/len(results),2)

    #return minimum_height,maximum_height,avg_height

    print(f"The max height is {maximum_height}. \n Minimum height is {minimum_height} \n Average height is {avg_height}")


eye_color('brown','black')
# Out:
# The max height is 191.
#  Minimum height is 163
#  Average height is 179.27
